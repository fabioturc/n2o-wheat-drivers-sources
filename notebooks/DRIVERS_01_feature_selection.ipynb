# %% [markdown]
# # LOAD LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from datetime import datetime
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error, r2_score
from xgboost import XGBRegressor

# %% [markdown]
# # CONFIGURATION

# %%
START_DATE, END_DATE = '2022-09-01', '2023-10-05'
TIME_RESOLUTION = '4'
TARGET_FLUX = 'n2o'
QUALITY_FLAG = 'qcf0'
N_FOLDS = 5
MODEL_TYPE = 'XGBoost'  # Options: 'RandomForest' or 'XGBoost'
LOG_TRANSFORM = False
ADD_ID = False
UNDERSAMPLE = False

# %% [markdown]
# # LOAD DATA

# %%
data = pd.read_csv(f'../data/processed/DRIVERS_dataset_{TIME_RESOLUTION}h.csv', low_memory=False)
data['timestamp_middle'] = pd.to_datetime(data['timestamp_middle'])
data.set_index('timestamp_middle', inplace=True)
data = data.loc[START_DATE:END_DATE]

# Add an id column to account for the proximity of values as the timestamp is continuous without gaps
if ADD_ID:
    data['id'] = range(0, len(data))

# %% [markdown]
# # CLEAN DATA

# %%
TARGET = f'flux_{TARGET_FLUX}_{QUALITY_FLAG}'

median_nan_size = (
    data[TARGET]
    .isna()
    .ne(data[TARGET].isna().shift())
    .cumsum()
    .where(data[TARGET].isna())
    .dropna()
    .value_counts()
    .median()
)
print("Median size of consecutive NaNs in the target variable:", median_nan_size)

# Remove NAs
data = data[data[TARGET].notna()]

# Keep only variables of the chosen categories
prefix = ('wfps', 'ts', 'prec', 'flux_gpp', 'n_decay_timed', 'timesince_fert', 'timesince_soil_preparation', 'timesince_harvest', f'flux_{TARGET_FLUX}')
to_keep = [c for c in data.columns if c.startswith(prefix) and '0.5' not in c]
data = data[to_keep].copy()

# Remove any flux variable with target flux except for the target itself
to_drop = [col for col in data.columns if TARGET_FLUX in col]
# Leave the target!
to_drop.remove(TARGET)
data.drop(columns=to_drop, inplace=True)

def clean_data(df, threshold=0.05):
    """Remove columns with too many missing values and non-numeric columns."""
    dropped_missing = df.columns[df.isna().mean() > threshold].tolist()
    df = df.drop(columns=dropped_missing)
    dropped_non_numeric = df.select_dtypes(exclude=[np.number]).columns.tolist()
    df = df.select_dtypes(include=[np.number])
    print(f"Dropped {len(dropped_missing)} due to missing values: {dropped_missing}")
    print(f"Dropped {len(dropped_non_numeric)} non-numeric columns: {dropped_non_numeric}")
    
    return df

data = clean_data(data)

data
# Out:
# Median size of consecutive NaNs in the target variable: 3.0
# Dropped 0 due to missing values: []
# Dropped 0 non-numeric columns: []
#                      flux_n2o_qcf0   flux_gpp  prec    ts_0.05    ts_0.15  \
# timestamp_middle
# 2022-09-01 04:00:00       0.242429   3.077580   0.0  17.577569  19.104306
# 2022-09-01 08:00:00      -0.020742  18.406707   0.0  18.016180  18.734653
# 2022-09-01 12:00:00      -0.233794  18.004702   0.0  20.296944  18.839792
# 2022-09-02 08:00:00      -0.265809  21.663946   0.0  17.921111  17.912916
# 2022-09-02 12:00:00      -0.433862  12.475740   0.0  22.167222  18.617500
# ...                            ...        ...   ...        ...        ...
# 2023-10-03 20:00:00       0.904912   1.391552   0.0  15.964653  16.568125
# 2023-10-04 08:00:00       0.781407   1.531960   0.0  14.847847  15.841875
# 2023-10-04 12:00:00       1.360674   1.279627   0.0  15.727778  15.859306
# 2023-10-04 16:00:00       1.672365   0.050183   0.0  15.602083  16.087570
# 2023-10-05 08:00:00       0.779912   2.260402   0.0  13.283194  14.786667
#
#                         ts_0.3  wfps_0.05  wfps_0.15   wfps_0.3  \
# timestamp_middle
# 2022-09-01 04:00:00  19.170764  29.051775  22.108163  31.018332
# 2022-09-01 08:00:00  18.886667  28.948170  21.917521  30.969499
# 2022-09-01 12:00:00  18.705625  29.102167  21.751624  30.864144
# 2022-09-02 08:00:00  18.202083  28.208974  21.083679  30.704594
# 2022-09-02 12:00:00  18.139514  28.670670  21.060803  30.600884
# ...                        ...        ...        ...        ...
# 2023-10-03 20:00:00  16.170069  35.452801  53.681349  53.224239
# 2023-10-04 08:00:00  15.936528  35.261959  53.215485  53.060850
# 2023-10-04 12:00:00  15.817709  33.884309  53.178821  52.927896
# 2023-10-04 16:00:00  15.856875  33.630346  53.129941  52.880800
# 2023-10-05 08:00:00  15.261458  33.915234  52.404679  52.597275
#
#                      n_decay_timed  ...  ts_0.3_diff48h  wfps_0.05_diff12h  \
# timestamp_middle                    ...
# 2022-09-01 04:00:00            0.0  ...       -0.404792          -1.062558
# 2022-09-01 08:00:00            0.0  ...       -0.436319          -0.646453
# 2022-09-01 12:00:00            0.0  ...       -0.582570          -0.193133
# 2022-09-02 08:00:00            0.0  ...       -1.271945          -0.358983
# 2022-09-02 12:00:00            0.0  ...       -1.232709           0.328727
# ...                            ...  ...             ...                ...
# 2023-10-03 20:00:00            0.0  ...       -0.018889          -0.810702
# 2023-10-04 08:00:00            0.0  ...        0.116250          -0.190842
# 2023-10-04 12:00:00            0.0  ...        0.090556          -1.547875
# 2023-10-04 16:00:00            0.0  ...       -0.025070          -2.010680
# 2023-10-05 08:00:00            0.0  ...       -0.669792           0.172904
#
#                      wfps_0.05_diff24h  wfps_0.05_diff48h  wfps_0.15_diff12h  \
# timestamp_middle
# 2022-09-01 04:00:00           1.028308           1.704769          -0.303753
# 2022-09-01 08:00:00           0.102948           2.387247          -0.499575
# 2022-09-01 12:00:00          -1.307600          -0.683744          -0.561318
# 2022-09-02 08:00:00          -0.739196          -0.636248          -0.657767
# 2022-09-02 12:00:00          -0.431497          -1.739097          -0.527953
# ...                                ...                ...                ...
# 2023-10-03 20:00:00          -0.677960          -2.364172          -0.163795
# 2023-10-04 08:00:00          -1.001544          -2.417786          -0.465864
# 2023-10-04 12:00:00          -1.319816          -2.506386          -0.356637
# 2023-10-04 16:00:00          -1.632363          -2.259856          -0.264668
# 2023-10-05 08:00:00          -1.346725          -2.348269          -0.578671
#
#                      wfps_0.15_diff24h  wfps_0.15_diff48h  wfps_0.3_diff12h  \
# timestamp_middle
# 2022-09-01 04:00:00          -0.094928          -0.469126         -0.077292
# 2022-09-01 08:00:00          -0.485645          -0.278392         -0.165390
# 2022-09-01 12:00:00          -0.651114          -0.275279         -0.225380
# 2022-09-02 08:00:00          -0.833842          -1.319487         -0.195572
# 2022-09-02 12:00:00          -0.690822          -1.341935         -0.247245
# ...                                ...                ...               ...
# 2023-10-03 20:00:00          -0.529972          -0.915471         -0.127161
# 2023-10-04 08:00:00          -0.629659          -0.944960         -0.163389
# 2023-10-04 12:00:00          -0.569158          -1.025921         -0.269625
# 2023-10-04 16:00:00          -0.584720          -1.148264         -0.265744
# 2023-10-05 08:00:00          -0.810806          -1.440466         -0.259704
#
#                      wfps_0.3_diff24h  wfps_0.3_diff48h
# timestamp_middle
# 2022-09-01 04:00:00          0.166907         -0.231051
# 2022-09-01 08:00:00          0.181054         -0.259238
# 2022-09-01 12:00:00         -0.100895         -0.249998
# 2022-09-02 08:00:00         -0.264905         -0.083852
# 2022-09-02 12:00:00         -0.263260         -0.364155
# ...                               ...               ...
# 2023-10-03 20:00:00         -0.317963         -0.554744
# 2023-10-04 08:00:00         -0.290550         -0.505746
# 2023-10-04 12:00:00         -0.314303         -0.559491
# 2023-10-04 16:00:00         -0.370044         -0.611150
# 2023-10-05 08:00:00         -0.463575         -0.754125
#
# [1118 rows x 79 columns]

# %% [markdown]
# Last 20% of data is kept as hold-out for model evaluation

# %%
# keep only the first 80%  of data
data = data.iloc[:int(0.8 * len(data))].copy()

# %% [markdown]
# # IMBALANCE HANDLING

# %% [markdown]
# ## UNDER SAMPLING

# %%
if UNDERSAMPLE:
    quantile_cutoff = 0.8
    cutoff_value = data[TARGET].quantile(quantile_cutoff)
    print(f'Undersampling target data below: {cutoff_value}')
    # Split and undersample
    upper = data[data[TARGET] > cutoff_value]
    lower = data[data[TARGET] <= cutoff_value]
    # Undersample
    lower_sampled = lower.sample(frac=0.5, random_state=42)
    # Combine
    data = pd.concat([upper, lower_sampled]).sample(frac=1, random_state=42)
    # Resort data
    data = data.sort_index().reset_index(drop=False)  # keep the timestamp as a column
    data = data.set_index('timestamp_middle')    # and set it back as index if needed
    # Plot
    data[TARGET].plot(x_compat=True, style='.');

# %% [markdown]
# ## LOG TRANSFORMATION

# %%
min_value = data[TARGET].min()

def log_transform(x):
    return np.log1p(x - min_value) if min_value < 0 else np.log1p(x)

def inverse_log_transform(x):
    return np.expm1(x) + min_value if min_value < 0 else np.expm1(x)

if LOG_TRANSFORM:
    data[TARGET] = log_transform(data[TARGET])
    print('The target was log transformed')
    # Show histogram of TARGET
    plt.hist(data[TARGET], bins=20)
    plt.xlabel(TARGET)
    plt.show()
    # Show timeseries
    data[TARGET].plot(x_compat=True, style='.');

# %% [markdown]
# # CROSS-VAL SPLITS

# %%
def create_splits(X, y, n_folds):
    """Creates train-test splits using KFold."""
    # Select method for splitting
    splitter = KFold(n_splits=n_folds, shuffle=False)
    # Generate train-test splits
    splits = [(train_idx, test_idx) for train_idx, test_idx in splitter.split(X, y)]
    return splits


X = data.drop(columns=TARGET)
y = data[TARGET]

# Create the splits
cross_val_splits = create_splits(X, y, n_folds=N_FOLDS)

# --- PLOT TRAIN-TEST SPLITS ---
n_rows = math.ceil(N_FOLDS / 2)  # Ensure enough rows for all splits
fig, axes = plt.subplots(n_rows, 2, figsize=(14, 8))
axes = axes.flatten()  # Flatten the axes array to make iteration easier

for i, (train_idx, test_idx) in enumerate(cross_val_splits):
    train_idx_mapped = X.iloc[train_idx].index
    test_idx_mapped = X.iloc[test_idx].index

    # Plot train and test points
    axes[i].plot(y.loc[train_idx_mapped].index, y.loc[train_idx_mapped], '.', label='Train', color="blue")
    axes[i].plot(y.loc[test_idx_mapped].index, y.loc[test_idx_mapped], 'x', label='Test', color="red")
    
    axes[i].set_title(f"Split {i + 1}")
    axes[i].legend()

# Hide unused subplots if n_folds is odd
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %%
def rfe_selection(X, y, cross_val_splits):
    performance = []
    iteration = 0
    features = list(X.columns)
    feature_removal_order = []  # Store removed features and their iteration index

    while len(features) > 1:
        iteration += 1
        rmse_scores, r2_scores, importances = [], [], []

        for train_idx, test_idx in cross_val_splits:
            X_train, y_train, X_test, y_test = X[features].iloc[train_idx], y.iloc[train_idx], X[features].iloc[test_idx], y.iloc[test_idx]
            model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1) if MODEL_TYPE == 'RandomForest' else XGBRegressor(n_estimators=100, random_state=42, n_jobs=-1)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            # Invert the transformation if it was applied to calculate the performance with the original scale
            if LOG_TRANSFORM:
                y_test, y_pred = inverse_log_transform(y_test), inverse_log_transform(y_pred)
            
            rmse_scores.append(root_mean_squared_error(y_test, y_pred))
            r2_scores.append(r2_score(y_test, y_pred))
            importances.append(model.feature_importances_)

        mean_rmse = np.mean(rmse_scores)
        mean_r2 = np.mean(r2_scores)
        performance.append((features.copy(), mean_rmse, mean_r2))

        mean_importances = np.mean(importances, axis=0)
        least_important_index = np.argmin(mean_importances)
        least_important_feature = features.pop(least_important_index)

        # Store the removed feature with its iteration index
        feature_removal_order.append((least_important_feature, iteration))

        print(f"Iteration {iteration}: Remaining features: {len(features)}, Removed: {least_important_feature}, RMSE: {mean_rmse:.4f}, R²: {mean_r2:.4f}")

    # Extract RMSE and R² values
    rmse_values = [score[1] for score in performance]
    r2_values = [score[2] for score in performance]

    # Plot RMSE and R² over iterations
    fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
    axs[0].plot(range(len(performance)), rmse_values, label="Cross-validated RMSE")
    axs[0].set_ylabel("RMSE")
    axs[0].legend()

    axs[1].plot(range(len(performance)), r2_values, label="Cross-validated R²", color="orange")
    axs[1].set_xlabel("Iteration")
    axs[1].set_ylabel("R²")
    axs[1].legend()

    plt.tight_layout()
    plt.show()

    # Select best feature set by minimizing both R² and RMSE and penlizing larger feature sets
    # Normalize RMSE and R²
    norm_rmse = (np.array(rmse_values) - min(rmse_values)) / (max(rmse_values) - min(rmse_values))
    norm_r2 = (np.array(r2_values) - min(r2_values)) / (max(r2_values) - min(r2_values))
    # Set weights for normalized metrics
    w_rmse, w_r2, w_penalty = 0.5, 0.5, 0.01  # Adjust w_penalty as needed
    # Calculate composite scores with normalized metrics and feature count penalty
    composite_scores = [
        (performance[i][0], # Features
         i + 1, # Iteration number
        w_rmse * norm_rmse[i] + w_r2 * (1 - norm_r2[i]) + w_penalty * len(performance[i][0])  # Composite score
        )  
        for i in range(len(performance))
    ]

    # Find the feature subset with the best (lowest) composite score
    best_features, best_iteration, _ = min(composite_scores, key=lambda x: x[2])

    # Add the final remaining feature
    feature_removal_order.append((features[0], iteration + 1))

    # Rank features based on removal order
    feature_ranking = [feature for feature, _ in sorted(feature_removal_order, key=lambda x: x[1], reverse=True)]

    # Print the best feature set details
    print(f"\nBest feature set found at iteration {best_iteration}:")
    print(f"Selected Features: {best_features}")
    print(f"Performance - RMSE: {rmse_values[best_iteration-1]:.4f}, R²: {r2_values[best_iteration-1]:.4f}")

    return best_features, feature_ranking


selected_features, ranked_features = rfe_selection(data.drop(columns=[TARGET]), data[TARGET], cross_val_splits= cross_val_splits)
# Update the main dataframe
data = data[selected_features + [TARGET]]
# Out:
# Iteration 1: Remaining features: 77, Removed: prec_lag48h, RMSE: 2.6809, R²: -7.5706
# Iteration 2: Remaining features: 76, Removed: timesince_harvest, RMSE: 2.6769, R²: -7.5482
# Iteration 3: Remaining features: 75, Removed: flux_gpp_lag12h, RMSE: 2.6754, R²: -7.5490
# Iteration 4: Remaining features: 74, Removed: wfps_0.15_diff24h, RMSE: 2.6758, R²: -7.2526
# Iteration 5: Remaining features: 73, Removed: wfps_0.05_roll48hmean, RMSE: 2.6729, R²: -7.1007
# Iteration 6: Remaining features: 72, Removed: ts_0.15_diff48h, RMSE: 2.6800, R²: -7.3662
# Iteration 7: Remaining features: 71, Removed: ts_0.3_diff24h, RMSE: 2.6398, R²: -5.9849
# Iteration 8: Remaining features: 70, Removed: wfps_0.15_roll48hmean, RMSE: 2.6517, R²: -6.8590
# Iteration 9: Remaining features: 69, Removed: wfps_0.3_lag24h, RMSE: 2.6473, R²: -6.7649
# Iteration 10: Remaining features: 68, Removed: ts_0.3_diff12h, RMSE: 2.6453, R²: -6.6411
# Iteration 11: Remaining features: 67, Removed: ts_0.3_roll24hmean, RMSE: 2.6366, R²: -6.2202
# Iteration 12: Remaining features: 66, Removed: ts_0.15_roll12hmean, RMSE: 2.6338, R²: -6.2270
# Iteration 13: Remaining features: 65, Removed: prec_lag24h, RMSE: 2.6333, R²: -6.1712
# Iteration 14: Remaining features: 64, Removed: wfps_0.05_diff12h, RMSE: 2.7367, R²: -7.0406
# Iteration 15: Remaining features: 63, Removed: ts_0.05_lag12h, RMSE: 2.7127, R²: -6.5226
# Iteration 16: Remaining features: 62, Removed: wfps_0.3_diff12h, RMSE: 2.7237, R²: -7.3169
# Iteration 17: Remaining features: 61, Removed: ts_0.15_diff24h, RMSE: 2.7513, R²: -7.8465
# Iteration 18: Remaining features: 60, Removed: flux_gpp_roll12hsum, RMSE: 2.7398, R²: -7.8601
# Iteration 19: Remaining features: 59, Removed: ts_0.3_diff48h, RMSE: 2.7028, R²: -6.5368
# Iteration 20: Remaining features: 58, Removed: ts_0.05_diff12h, RMSE: 2.7389, R²: -7.8726
# Iteration 21: Remaining features: 57, Removed: wfps_0.3, RMSE: 2.7376, R²: -6.8930
# Iteration 22: Remaining features: 56, Removed: ts_0.05_lag24h, RMSE: 2.7226, R²: -6.2338
# Iteration 23: Remaining features: 55, Removed: ts_0.15_diff12h, RMSE: 2.7398, R²: -7.3065
# Iteration 24: Remaining features: 54, Removed: wfps_0.15_diff12h, RMSE: 2.7729, R²: -7.6861
# Iteration 25: Remaining features: 53, Removed: ts_0.15_lag24h, RMSE: 2.7693, R²: -8.4266
# Iteration 26: Remaining features: 52, Removed: flux_gpp_lag24h, RMSE: 2.7422, R²: -7.8057
# Iteration 27: Remaining features: 51, Removed: prec, RMSE: 2.7225, R²: -6.5509
# Iteration 28: Remaining features: 50, Removed: ts_0.05_diff24h, RMSE: 2.7140, R²: -6.3363
# Iteration 29: Remaining features: 49, Removed: wfps_0.05_roll24hmean, RMSE: 2.7479, R²: -7.4187
# Iteration 30: Remaining features: 48, Removed: flux_gpp_roll24hsum, RMSE: 2.7211, R²: -6.7018
# Iteration 31: Remaining features: 47, Removed: flux_gpp_lag48h, RMSE: 2.7305, R²: -7.0091
# Iteration 32: Remaining features: 46, Removed: ts_0.15_lag48h, RMSE: 2.6718, R²: -6.8180
# Iteration 33: Remaining features: 45, Removed: wfps_0.05_lag24h, RMSE: 2.6914, R²: -7.7452
# Iteration 34: Remaining features: 44, Removed: ts_0.05_lag48h, RMSE: 2.6524, R²: -6.0299
# Iteration 35: Remaining features: 43, Removed: wfps_0.15_roll12hmean, RMSE: 2.7700, R²: -7.2736
# Iteration 36: Remaining features: 42, Removed: ts_0.05_diff48h, RMSE: 2.7924, R²: -7.3991
# Iteration 37: Remaining features: 41, Removed: ts_0.3, RMSE: 2.7759, R²: -7.5388
# Iteration 38: Remaining features: 40, Removed: prec_roll12hsum, RMSE: 2.7839, R²: -7.4020
# Iteration 39: Remaining features: 39, Removed: wfps_0.15, RMSE: 2.7763, R²: -7.3308
# Iteration 40: Remaining features: 38, Removed: flux_gpp, RMSE: 2.7420, R²: -6.1778
# Iteration 41: Remaining features: 37, Removed: wfps_0.05, RMSE: 2.8454, R²: -7.5983
# Iteration 42: Remaining features: 36, Removed: wfps_0.05_lag12h, RMSE: 2.7848, R²: -6.1864
# Iteration 43: Remaining features: 35, Removed: ts_0.15, RMSE: 2.7787, R²: -7.1061
# Iteration 44: Remaining features: 34, Removed: ts_0.05, RMSE: 2.7336, R²: -7.9557
# Iteration 45: Remaining features: 33, Removed: ts_0.15_lag12h, RMSE: 2.6147, R²: -6.1022
# Iteration 46: Remaining features: 32, Removed: ts_0.3_lag12h, RMSE: 2.5785, R²: -6.8698
# Iteration 47: Remaining features: 31, Removed: ts_0.3_lag24h, RMSE: 2.5743, R²: -7.1832
# Iteration 48: Remaining features: 30, Removed: ts_0.3_lag48h, RMSE: 2.6000, R²: -7.8623
# Iteration 49: Remaining features: 29, Removed: wfps_0.05_lag48h, RMSE: 2.5744, R²: -6.6749
# Iteration 50: Remaining features: 28, Removed: wfps_0.15_lag24h, RMSE: 2.6545, R²: -10.0124
# Iteration 51: Remaining features: 27, Removed: wfps_0.3_diff48h, RMSE: 2.5771, R²: -7.6524
# Iteration 52: Remaining features: 26, Removed: ts_0.05_roll12hmean, RMSE: 2.5545, R²: -6.7638
# Iteration 53: Remaining features: 25, Removed: wfps_0.15_roll24hmean, RMSE: 2.5884, R²: -6.3133
# Iteration 54: Remaining features: 24, Removed: wfps_0.15_lag12h, RMSE: 2.6177, R²: -8.1232
# Iteration 55: Remaining features: 23, Removed: wfps_0.3_roll24hmean, RMSE: 2.5616, R²: -5.8191
# Iteration 56: Remaining features: 22, Removed: wfps_0.3_lag12h, RMSE: 2.5693, R²: -5.8392
# Iteration 57: Remaining features: 21, Removed: ts_0.3_roll12hmean, RMSE: 2.6133, R²: -7.8946
# Iteration 58: Remaining features: 20, Removed: wfps_0.15_diff48h, RMSE: 2.6928, R²: -9.3393
# Iteration 59: Remaining features: 19, Removed: wfps_0.15_lag48h, RMSE: 2.7034, R²: -8.5890
# Iteration 60: Remaining features: 18, Removed: prec_lag12h, RMSE: 2.1776, R²: -6.3209
# Iteration 61: Remaining features: 17, Removed: prec_roll48hsum, RMSE: 2.1748, R²: -5.2514
# Iteration 62: Remaining features: 16, Removed: wfps_0.05_diff48h, RMSE: 2.2115, R²: -6.6705
# Iteration 63: Remaining features: 15, Removed: ts_0.05_roll24hmean, RMSE: 2.1441, R²: -5.4456
# Iteration 64: Remaining features: 14, Removed: wfps_0.05_diff24h, RMSE: 2.1421, R²: -5.2110
# Iteration 65: Remaining features: 13, Removed: ts_0.05_roll48hmean, RMSE: 2.1639, R²: -6.1830
# Iteration 66: Remaining features: 12, Removed: wfps_0.05_roll12hmean, RMSE: 2.1859, R²: -5.4354
# Iteration 67: Remaining features: 11, Removed: prec_roll24hsum, RMSE: 2.1647, R²: -5.5886
# Iteration 68: Remaining features: 10, Removed: flux_gpp_roll48hsum, RMSE: 2.1445, R²: -3.7476
# Iteration 69: Remaining features: 9, Removed: ts_0.15_roll24hmean, RMSE: 2.1578, R²: -4.8379
# Iteration 70: Remaining features: 8, Removed: wfps_0.3_roll12hmean, RMSE: 2.1862, R²: -2.4897
# Iteration 71: Remaining features: 7, Removed: ts_0.15_roll48hmean, RMSE: 2.2198, R²: -3.0544
# Iteration 72: Remaining features: 6, Removed: ts_0.3_roll48hmean, RMSE: 2.2905, R²: -4.0299
# Iteration 73: Remaining features: 5, Removed: wfps_0.3_diff24h, RMSE: 2.1868, R²: -2.6578
# Iteration 74: Remaining features: 4, Removed: wfps_0.3_roll48hmean, RMSE: 2.2097, R²: -2.7689
# Iteration 75: Remaining features: 3, Removed: wfps_0.3_lag48h, RMSE: 2.3698, R²: -2.9537
# Iteration 76: Remaining features: 2, Removed: timesince_soil_preparation, RMSE: 2.2458, R²: -2.1834
# Iteration 77: Remaining features: 1, Removed: timesince_fert, RMSE: 2.2589, R²: -2.3268
# Best feature set found at iteration 76:
# Selected Features: ['n_decay_timed', 'timesince_soil_preparation', 'timesince_fert']
# Performance - RMSE: 2.2458, R²: -2.1834

# %% [markdown]
# # EXPORT

# %%
filename = '../data/processed/best_features_' + TARGET_FLUX + '_' + MODEL_TYPE + '_' + TIME_RESOLUTION + 'h.txt'
with open(filename, 'w') as f:
    for item in selected_features:
        f.write(f"{item}\n")

filename = '../data/processed/ranked_features_' + TARGET_FLUX + '_' + MODEL_TYPE + '_' + TIME_RESOLUTION + 'h.txt'
with open(filename, 'w') as f:
    for item in ranked_features:
        f.write(f"{item}\n")

# %% [markdown]
# # **End of notebook**

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2026-06-16 17:03:43
